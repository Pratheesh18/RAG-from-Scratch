# %% [markdown]
# ### Data Ingestion

# %%
### document datastrcuture 

from langchain_core.documents import Document

# %%
# why we need meta data - when doing similarity search we can apply filters using these meta data
doc = Document(
    page_content = "This is the main text content I am using to create RAG",
    metadata = {
        "source" : "example.text",
        "pages":1,
        "author" : "Pratheesh",
        "date_created" : "2026-01-01"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.text', 'pages': 1, 'author': 'Pratheesh', 'date_created': '2026-01-01'}, page_content='This is the main text content I am using to create RAG')

# %%
## Create a simple text file
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
### TextLoader
# from langchain.document_loaders import TextLoader
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
### Directory Loader
from langchain_community.document_loaders import DirectoryLoader

## load all the text files from the directory
dir_loader = DirectoryLoader(
    "../data/text_files",
    glob = "**/*.txt", #Pattern to match files
    loader_cls = TextLoader,
    show_progress=False
)

documents = dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    '),
#  Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import PyPDFLoader , PyMuPDFLoader

dir_loader = DirectoryLoader(
    "../data/pdf",
    glob = "**/*.pdf",
    loader_cls = PyMuPDFLoader,
    show_progress = False
)

pdf_document = dir_loader.load()
pdf_document
# Out:
# [Document(metadata={'producer': 'iOS Version 17.5.1 (Build 21F90) Quartz PDFContext', 'creator': 'Notes', 'creationdate': "D:20240806141133Z00'00'", 'source': '..\\data\\pdf\\Back Side of Birth Certificate.pdf', 'file_path': '..\\data\\pdf\\Back Side of Birth Certificate.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': '08. If the father was', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20240806141133Z00'00'", 'trapped': '', 'modDate': "D:20240806141133Z00'00'", 'creationDate': "D:20240806141133Z00'00'", 'page': 0}, page_content=''),
#  Document(metadata={'producer': 'iOS Version 17.5.1 (Build 21F90) Quartz PDFContext', 'creator': 'Notes', 'creationdate': "D:20240806141058Z00'00'", 'source': '..\\data\\pdf\\Front Page of Birth Certificate.pdf', 'file_path': '..\\data\\pdf\\Front Page of Birth Certificate.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': 'ENGLISH TRANSLATION', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20240806141058Z00'00'", 'trapped': '', 'modDate': "D:20240806141058Z00'00'", 'creationDate': "D:20240806141058Z00'00'", 'page': 0}, page_content=''),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2026-01-08T04:55:44+00:00', 'source': '..\\data\\pdf\\Pratheesh Balachandran_Resume.pdf', 'file_path': '..\\data\\pdf\\Pratheesh Balachandran_Resume.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': 'Purple and White Clean and Professional Resume', 'author': 'Pratheesh dot', 'subject': '', 'keywords': 'DAGCq6UxuMQ,BAFEbb8td-A,0', 'moddate': '2026-01-08T04:55:43+00:00', 'trapped': '', 'modDate': "D:20260108045543+00'00'", 'creationDate': "D:20260108045544+00'00'", 'page': 0}, page_content='Pratheesh18\npratheesh1218@gmail.com\nPratheesh Balachandran\n+94 701681953\nProfessional Experience\nN-Ach | Associate Software Engineer\n2023 Nov - 2024 Mar\nE-Commerce Web Application Development : Developed e-commerce web application with role-\nbased authentication and authorization(RBAC) using React JS , ensuring secure and user-friendly\ninterfaces . \nLeveraged Material UI to create responsive and visually appealing user interfaces , improving the\noverall user experience.\nState Management & API Optimization : Utilized Redux Toolkit for efficient state management and\nRTK Query for streamlined API calls , significantly enhancing application performance and\nmaintainability.\nVersion Control & Collaboration : Used GitHub for version control and collaboration , managing\nrepositories , reviewing pull requests and ensuring seamless code integration and team collaboration .\nProject Management : Utilized ClickUp to to track tasks , manage deadlines and oversee user stories ,\ntasks and sprints , ensuring timely delivery of milestones and seamless project execution\nPRATHEESH BALACHANDRAN\nNo 6/9 , Ben & Nancy Tower , Ramakrishna Road , Wellawatte \n2022 Aug - 2023 Jan\nH- Town Technologies | Intern Frontend Developer\nChat Application Development  :   Collaborated with the frontend team to develop a chat application\nfeaturing VoIP texting capabilities using React JS and Material UI.\nImplemented real-time messaging and VoIP functionalities, enhancing user communication within the\napplication .\nState Management : Utilized Redux for state management, ensuring a predictable state container and\nefficient handling of application states across various components\nRevamped application architecture by refactoring 100% of class-based components to functional\ncomonents\nProject Management : Utilized  JIRA for project management, effectively tracking tasks, managing\ndeadlines, and overseeing user stories, tasks, and sprints to ensure timely delivery of project\nmilestones and seamless project execution\nVersion Control & Collaboration : Used Bitbucket for version control and collaboration, managing\nrepositories, reviewing pull requests, and ensuring seamless code integration and team collaboration.\n2020-2023\nEducation\nBSc(Hons) in Information Technology specializing in Software Engineering\nInstitution - Sri Lanka Institute of Information Technology\nCUBE | .NET Developer\nRegtech Platform : Using C# and  .NET to develop backend apis for content capture systems.\nUsing Azure services to support microservices-based content management solutions . \nUsing JIRA for project management and Bitbucket for code collaboration\n2025 Jan - present'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2026-01-08T04:55:44+00:00', 'source': '..\\data\\pdf\\Pratheesh Balachandran_Resume.pdf', 'file_path': '..\\data\\pdf\\Pratheesh Balachandran_Resume.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': 'Purple and White Clean and Professional Resume', 'author': 'Pratheesh dot', 'subject': '', 'keywords': 'DAGCq6UxuMQ,BAFEbb8td-A,0', 'moddate': '2026-01-08T04:55:43+00:00', 'trapped': '', 'modDate': "D:20260108045543+00'00'", 'creationDate': "D:20260108045544+00'00'", 'page': 1}, page_content='Submitted a research paper titled as  ‘Image Classification of Disease Detection in Paddy\nCrops Using Transfer Learning Approach ‘ .\nConference  - 2023 5th International Conference on Advancements in Computing (ICAC)\n             \nPublications\nSkills\nReact Native\nExpress JS | Koa JS\nNode JS\nMongo DB | My SQL |Firebase\nHTML/CSS\nJava\nJavascript\nTypescript\nPython\nReact JS\nGit \nGithub\nGitLab\nBitbucket\nDocker\nKubernetes\nMachine Learning\nDeep Learning\nAdaptability\nProblem Solving\nJIRA\nClickUp\nAgile\n2 . A-Level Exam Practice App\nDeveloping  an interactive web application to help Sri Lankan A-Level students practice past paper\nquestions , featuring adaptive learning with subquestions for incorrect answers to reinforce\nunderstanding\nHere are some key features : Multiple-choice questions with real-time feedback , Dynamic\nsubquestion generation for wrong answers using AI.\nUsing React JS(TypeScript) , Material UI for frontend and Node JS , Express JS for backend .\nGoogle Gemini API for subquestion generation . \nLeveraged Axios to handle API requests and manage data flow between the frontend and backend.\n1 . Disease Prediction Application(Research Project)\nThis project involved identifying diseased leaves in the paddy crops using CNN(Convolutional\nNeural Networks).\nLeveraged TensorFlow and Keras to build and train the model, ensuring high accuracy and robust\nperformance\nUtilized Kaggle to collect a comprehensive dataset of diseased and healthy paddy crop images,\nensuring a diverse and representative dataset for training and validation.\nDeveloped a user-friendly web and mobile application using React JS  and React Native for the\nfrontend and Flask for the backend.\nEmployed a range of technologies including  Pandas, NumPy, and Scikit-learn for data processing,\nmodel training, and evaluation\nEnabled users to upload images of paddy crops and receive immediate disease predictions based on\nthe trained CNN model\nProjects\nReferences\n1 . Mr.Sanjay Lonkar\nTechnical Director\n      H-Town Technologies\nContact No : +91 9373081809\n2 . Mr.Achintha Perera\nProject Manager\nN-Ach\nContact No :  +971 551345668')]
